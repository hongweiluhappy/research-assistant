# %%
import os
os.environ["GEMINI_API_KEY"] = "AIzaSyDFFxZkwlyPQfynSoJTm4XNi3IVS7J14wU"

# %%
import google.generativeai as genai
import ipywidgets as widgets
from IPython.display import display, Markdown

# 配置 Gemini
genai.configure(api_key=os.environ["GEMINI_API_KEY"])
model = genai.GenerativeModel("gemini-2.5-flash")

# 科研助手函数
def research_search_assistant(user_question: str):
    prompt = f"""
你是一个科研搜索助手，帮用户高效拆解科研问题、推荐数据库、总结结果。
请按如下步骤回答用户的问题：

1. 🔍 拆解问题：
   - 拆成多个子问题，引导用户聚焦目标
   - 推理用户的研究意图，提示缺失信息（如时间、地区、疾病、变量等）

2. 📚 推荐数据库与关键词：
   - 给出适合的数据库（英文名 + 链接）
   - 给出可用于搜索的关键词组合

3. 📄 模拟输出结构化科研结论（基于假设文献）：
   - 研究目的：
   - 研究方法：
   - 研究结果：
   - 研究结论：

4. 📎 在最后列出结论小注标，并附带参考链接。

用户问题如下：
{user_question}
    """
    response = model.generate_content(prompt)
    return response.text

# Jupyter交互控件
input_box = widgets.Text(
    value='全球传染病监测情况',
    placeholder='请输入你的科研问题',
    description='问题:',
    layout=widgets.Layout(width='80%')
)
output_box = widgets.Output()
button = widgets.Button(description="搜索", button_style='success')

def on_button_click(b):
    output_box.clear_output()
    user_question = input_box.value
    result = research_search_assistant(user_question)
    with output_box:
        display(Markdown(f"### 🔍 搜索结果\n\n{result}"))

button.on_click(on_button_click)

display(widgets.VBox([input_box, button, output_box]))
# Out:
# 您好！“全球传染病监测情况”是一个非常宏观且重要的研究方向。为了更好地为您提供帮助，我们需要进一步明确您的具体需求。
#
# ---
#
# ### 1. 🔍 拆解问题
#
# 您的提问“全球传染病监测情况”非常广泛，可能涉及多个层面。为了帮助您聚焦并获得更精准的信息，请考虑以下子问题和潜在的研究意图：
#
# *   **您想了解全球传染病监测的哪个特定时期？**
#     *   是当前（例如，最近1-2年）的情况？
#     *   是COVID-19大流行前后（例如，大流行如何改变了监测）的对比？
#     *   还是更长期的发展趋势？
# *   **您对监测的哪些具体方面感兴趣？**
#     *   **系统类型：** 例如，早期预警系统（EWS）、实验室网络、哨点监测系统、基于事件的监测（EBS）？
#     *   **技术应用：** 例如，基因组监测（Genomic Surveillance）、人工智能（AI）在监测中的应用、数字健康工具、废水监测？
#     *   **数据方面：** 例如，数据收集、数据共享机制、数据分析、数据可视化？
#     *   **政策与治理：** 例如，国际卫生条例（IHR）的实施情况、全球合作框架、资金投入？
#     *   **面临的挑战：** 例如，资金不足、人力资源短缺、数据孤岛、公平性问题、“一体化健康”（One Health）理念的整合？
#     *   **特定疾病的监测：** 例如，流感、COVID-19、猴痘、耐药菌、人畜共患病等？
# *   **您的研究目的是什么？**
#     *   是为了撰写一份综述（Review）以全面了解该领域？
#     *   是为了评估当前监测系统的效率或有效性？
#     *   是为了探讨未来传染病监测的发展趋势和创新？
#     *   是为了了解特定国家或地区的监测实践？
#
# **推理您的研究意图：** 鉴于您的问题非常概括，我初步推断您可能希望获得一个关于**当前全球传染病监测的整体概览，包括其主要组成、面临的挑战以及未来的发展方向，可能尤其关注COVID-19大流行后的变化和增强措施。**
#
# ---
#
# ### 2. 📚 推荐数据库与关键词
#
# ...
